# %% [markdown]
# # 군집화 (Clustering)
# - 결과데이터가 없는 데이터를 그룹화 하는 비지도 학습
#
# # K-means
# - 개발자가 군집의 개수를 정해주면 거리가 가까운 데이터들 끼리 정해진 개수만큼의 그룹으로 그룹화된다.
# - 이상치에 매우 민감하다.
# - 대부분의 군집 작업에서 사용된다.

# %%
# 기본
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os
import cv2

# 군집화
from sklearn.cluster import KMeans

# 경고 뜨지 않게 설정
import warnings
warnings.filterwarnings('ignore')

# 그래프 설정
plt.rcParams['font.family'] = 'Malgun Gothic'
# plt.rcParams['font.family'] = 'AppleGothic'
plt.rcParams['font.size'] = 16
plt.rcParams['figure.figsize'] = 20, 10
plt.rcParams['axes.unicode_minus'] = False

# %% [markdown]
# ### 데이터를 읽어온다.

# %%
iris_df = pd.read_csv('./data/Images_values_400.csv')
iris_df.head()
# Out:
#    Unnamed: 0  눈썹_길이     눈썹_굵기    눈썹_기울기     눈_세로길이  눈_가로길이        비율  \
# 0           0   67.0  6.833333  0.014286  31.833333    42.0  0.757937
# 1           1   72.5  8.500000  0.013514  33.000000    46.5  0.709677
# 2           2   64.0  6.166667  0.046154  28.833333    41.0  0.703252
# 3           3   67.0  7.500000  0.014286  33.666667    42.0  0.801587
# 4           4   72.0  9.333333  0.039474  44.500000    47.0  0.946809
#
#    눈_눈꼬리기울기      얼굴비율  코_길이  코_폭  콧볼_폭     입_크기  입_윗입술(두께)  입_아랫입술(두께)  입_입꼬리  \
# 0  0.011905  0.877953    75   42    58  1657.92      11.00       14.00  -0.06
# 1  0.011563  0.811448    94   50    70  2268.65      12.00       16.00   0.07
# 2  0.000000  0.915966    68   44    60  1916.97      13.00       15.00  -0.03
# 3  0.000000  0.852140    80   42    56  1703.45      11.33       14.67   0.03
# 4  0.000000  0.839858    94   46    64  2026.09       9.67       14.00   0.14
#
#       턱기울기1     턱기울기2     턱아래면적
# 0  2.771578  0.519215  0.600757
# 1  2.860961  0.532870  0.782105
# 2  2.506059  0.375494  0.497536
# 3  2.539327  0.447180  0.576929
# 4  2.283117  0.463311  0.673224

# %%
iris_df.drop(["Unnamed: 0"], axis=1, inplace=True)
iris_df
# Out:
#      눈썹_길이     눈썹_굵기    눈썹_기울기     눈_세로길이  눈_가로길이        비율  눈_눈꼬리기울기  \
# 0     67.0  6.833333  0.014286  31.833333    42.0  0.757937  0.011905
# 1     72.5  8.500000  0.013514  33.000000    46.5  0.709677  0.011563
# 2     64.0  6.166667  0.046154  28.833333    41.0  0.703252  0.000000
# 3     67.0  7.500000  0.014286  33.666667    42.0  0.801587  0.000000
# 4     72.0  9.333333  0.039474  44.500000    47.0  0.946809  0.000000
# ..     ...       ...       ...        ...     ...       ...       ...
# 395   68.0  8.000000  0.028571  30.666667    41.5  0.738956  0.025261
# 396   73.0  9.166667  0.027027  36.833333    45.5  0.809524  0.013540
# 397   73.5  8.500000  0.026316  34.000000    46.0  0.739130 -0.010870
# 398   63.0  7.666667  0.072464  33.666667    41.0  0.821138  0.008929
# 399   66.5  7.333333  0.014085  30.666667    41.5  0.738956  0.011034
#
#          얼굴비율  코_길이  코_폭  콧볼_폭     입_크기  입_윗입술(두께)  입_아랫입술(두께)  입_입꼬리  \
# 0    0.877953    75   42    58  1657.92      11.00       14.00  -0.06
# 1    0.811448    94   50    70  2268.65      12.00       16.00   0.07
# 2    0.915966    68   44    60  1916.97      13.00       15.00  -0.03
# 3    0.852140    80   42    56  1703.45      11.33       14.67   0.03
# 4    0.839858    94   46    64  2026.09       9.67       14.00   0.14
# ..        ...   ...  ...   ...      ...        ...         ...    ...
# 395  0.843866    81   43    60  1766.25      11.00       13.00  -0.05
# 396  0.813793    90   49    68  2135.20      12.67       14.00  -0.02
# 397  0.858156    85   49    69  2119.50      11.67       14.00   0.05
# 398  0.809339    83   42    60  1639.08      10.33       13.67   0.15
# 399  0.885375    76   42    58  1601.40      11.00       13.00  -0.06
#
#         턱기울기1     턱기울기2     턱아래면적
# 0    2.771578  0.519215  0.600757
# 1    2.860961  0.532870  0.782105
# 2    2.506059  0.375494  0.497536
# 3    2.539327  0.447180  0.576929
# 4    2.283117  0.463311  0.673224
# ..        ...       ...       ...
# 395  2.633969  0.286368  0.539663
# 396  2.661217  0.354672  0.621064
# 397  2.552671  0.353807  0.630400
# 398  2.782234  0.620375  0.583769
# 399  2.627174  0.399234  0.541679
#
# [400 rows x 18 columns]

# %%
X = iris_df

# %% [markdown]
# ### 군집화

# %%
# n_clusters : 군집의 개수, 생성되는 센트로이드의 개수
kmeans = KMeans(n_clusters=5)
kmeans.fit(X)
# Out:
# KMeans(n_clusters=5)

# %%
# 군집의 결과를 가져온다.
kmeans.labels_
# Out:
# array([1, 4, 3, 1, 0, 1, 1, 3, 0, 4, 1, 3, 3, 3, 1, 0, 3, 3, 3, 3, 3, 0,
#        2, 0, 3, 4, 1, 1, 3, 1, 2, 3, 4, 1, 1, 0, 0, 1, 1, 3, 1, 3, 1, 1,
#        2, 4, 4, 4, 0, 4, 3, 3, 0, 1, 0, 0, 1, 0, 3, 3, 2, 2, 3, 0, 3, 3,
#        3, 4, 2, 3, 3, 3, 2, 3, 3, 3, 0, 4, 4, 4, 3, 0, 0, 3, 3, 4, 1, 1,
#        3, 0, 1, 0, 3, 0, 4, 0, 2, 4, 3, 1, 0, 0, 3, 1, 0, 3, 2, 4, 3, 0,
#        0, 4, 1, 1, 1, 4, 0, 4, 0, 4, 0, 2, 3, 1, 3, 4, 4, 0, 1, 1, 2, 3,
#        3, 4, 0, 1, 3, 0, 1, 0, 0, 0, 3, 1, 1, 2, 3, 3, 3, 0, 2, 4, 0, 0,
#        2, 0, 0, 0, 1, 4, 4, 1, 3, 3, 0, 2, 1, 3, 4, 4, 3, 0, 3, 0, 1, 4,
#        0, 4, 2, 2, 0, 0, 2, 1, 4, 1, 3, 4, 1, 4, 0, 2, 3, 0, 0, 1, 1, 0,
#        3, 3, 4, 2, 1, 4, 0, 2, 0, 0, 4, 3, 4, 0, 3, 0, 3, 1, 0, 1, 3, 0,
#        3, 3, 2, 4, 3, 0, 4, 3, 0, 1, 3, 3, 0, 0, 4, 0, 1, 0, 4, 0, 3, 0,
#        3, 1, 4, 3, 2, 3, 0, 3, 3, 3, 3, 0, 3, 3, 3, 0, 4, 3, 1, 3, 1, 2,
#        3, 4, 3, 0, 4, 0, 4, 3, 0, 3, 1, 0, 3, 0, 3, 3, 0, 3, 4, 1, 1, 1,
#        0, 4, 3, 4, 0, 0, 3, 4, 3, 0, 0, 0, 2, 3, 4, 0, 3, 2, 3, 4, 3, 3,
#        0, 3, 1, 0, 0, 2, 0, 4, 1, 0, 4, 4, 0, 0, 0, 0, 3, 0, 0, 0, 4, 4,
#        0, 3, 1, 0, 3, 0, 1, 3, 0, 4, 1, 3, 3, 0, 0, 3, 0, 1, 4, 0, 4, 1,
#        2, 0, 4, 0, 3, 3, 4, 2, 3, 3, 3, 3, 0, 1, 1, 0, 4, 1, 3, 0, 0, 0,
#        1, 0, 1, 3, 3, 1, 3, 2, 4, 3, 1, 4, 4, 3, 4, 4, 3, 4, 2, 0, 4, 3,
#        0, 0, 1, 1])

# %%
kmeans.labels_
# Out:
# array([1, 4, 3, 1, 0, 1, 1, 3, 0, 4, 1, 3, 3, 3, 1, 0, 3, 3, 3, 3, 3, 0,
#        2, 0, 3, 4, 1, 1, 3, 1, 2, 3, 4, 1, 1, 0, 0, 1, 1, 3, 1, 3, 1, 1,
#        2, 4, 4, 4, 0, 4, 3, 3, 0, 1, 0, 0, 1, 0, 3, 3, 2, 2, 3, 0, 3, 3,
#        3, 4, 2, 3, 3, 3, 2, 3, 3, 3, 0, 4, 4, 4, 3, 0, 0, 3, 3, 4, 1, 1,
#        3, 0, 1, 0, 3, 0, 4, 0, 2, 4, 3, 1, 0, 0, 3, 1, 0, 3, 2, 4, 3, 0,
#        0, 4, 1, 1, 1, 4, 0, 4, 0, 4, 0, 2, 3, 1, 3, 4, 4, 0, 1, 1, 2, 3,
#        3, 4, 0, 1, 3, 0, 1, 0, 0, 0, 3, 1, 1, 2, 3, 3, 3, 0, 2, 4, 0, 0,
#        2, 0, 0, 0, 1, 4, 4, 1, 3, 3, 0, 2, 1, 3, 4, 4, 3, 0, 3, 0, 1, 4,
#        0, 4, 2, 2, 0, 0, 2, 1, 4, 1, 3, 4, 1, 4, 0, 2, 3, 0, 0, 1, 1, 0,
#        3, 3, 4, 2, 1, 4, 0, 2, 0, 0, 4, 3, 4, 0, 3, 0, 3, 1, 0, 1, 3, 0,
#        3, 3, 2, 4, 3, 0, 4, 3, 0, 1, 3, 3, 0, 0, 4, 0, 1, 0, 4, 0, 3, 0,
#        3, 1, 4, 3, 2, 3, 0, 3, 3, 3, 3, 0, 3, 3, 3, 0, 4, 3, 1, 3, 1, 2,
#        3, 4, 3, 0, 4, 0, 4, 3, 0, 3, 1, 0, 3, 0, 3, 3, 0, 3, 4, 1, 1, 1,
#        0, 4, 3, 4, 0, 0, 3, 4, 3, 0, 0, 0, 2, 3, 4, 0, 3, 2, 3, 4, 3, 3,
#        0, 3, 1, 0, 0, 2, 0, 4, 1, 0, 4, 4, 0, 0, 0, 0, 3, 0, 0, 0, 4, 4,
#        0, 3, 1, 0, 3, 0, 1, 3, 0, 4, 1, 3, 3, 0, 0, 3, 0, 1, 4, 0, 4, 1,
#        2, 0, 4, 0, 3, 3, 4, 2, 3, 3, 3, 3, 0, 1, 1, 0, 4, 1, 3, 0, 0, 0,
#        1, 0, 1, 3, 3, 1, 3, 2, 4, 3, 1, 4, 4, 3, 4, 4, 3, 4, 2, 0, 4, 3,
#        0, 0, 1, 1])

# %%
# 예측 결과를 가진 데이터프레임 생성을 위해 입력데이터를 복제한다.
predict_df = X.copy()
predict_df['target'] = kmeans.labels_
predict_df
# Out:
#      눈썹_길이     눈썹_굵기    눈썹_기울기     눈_세로길이  눈_가로길이        비율  눈_눈꼬리기울기  \
# 0     67.0  6.833333  0.014286  31.833333    42.0  0.757937  0.011905
# 1     72.5  8.500000  0.013514  33.000000    46.5  0.709677  0.011563
# 2     64.0  6.166667  0.046154  28.833333    41.0  0.703252  0.000000
# 3     67.0  7.500000  0.014286  33.666667    42.0  0.801587  0.000000
# 4     72.0  9.333333  0.039474  44.500000    47.0  0.946809  0.000000
# ..     ...       ...       ...        ...     ...       ...       ...
# 395   68.0  8.000000  0.028571  30.666667    41.5  0.738956  0.025261
# 396   73.0  9.166667  0.027027  36.833333    45.5  0.809524  0.013540
# 397   73.5  8.500000  0.026316  34.000000    46.0  0.739130 -0.010870
# 398   63.0  7.666667  0.072464  33.666667    41.0  0.821138  0.008929
# 399   66.5  7.333333  0.014085  30.666667    41.5  0.738956  0.011034
#
#          얼굴비율  코_길이  코_폭  콧볼_폭     입_크기  입_윗입술(두께)  입_아랫입술(두께)  입_입꼬리  \
# 0    0.877953    75   42    58  1657.92      11.00       14.00  -0.06
# 1    0.811448    94   50    70  2268.65      12.00       16.00   0.07
# 2    0.915966    68   44    60  1916.97      13.00       15.00  -0.03
# 3    0.852140    80   42    56  1703.45      11.33       14.67   0.03
# 4    0.839858    94   46    64  2026.09       9.67       14.00   0.14
# ..        ...   ...  ...   ...      ...        ...         ...    ...
# 395  0.843866    81   43    60  1766.25      11.00       13.00  -0.05
# 396  0.813793    90   49    68  2135.20      12.67       14.00  -0.02
# 397  0.858156    85   49    69  2119.50      11.67       14.00   0.05
# 398  0.809339    83   42    60  1639.08      10.33       13.67   0.15
# 399  0.885375    76   42    58  1601.40      11.00       13.00  -0.06
#
#         턱기울기1     턱기울기2     턱아래면적  target
# 0    2.771578  0.519215  0.600757       1
# 1    2.860961  0.532870  0.782105       4
# 2    2.506059  0.375494  0.497536       3
# 3    2.539327  0.447180  0.576929       1
# 4    2.283117  0.463311  0.673224       0
# ..        ...       ...       ...     ...
# 395  2.633969  0.286368  0.539663       3
# 396  2.661217  0.354672  0.621064       0
# 397  2.552671  0.353807  0.630400       0
# 398  2.782234  0.620375  0.583769       1
# 399  2.627174  0.399234  0.541679       1
#
# [400 rows x 19 columns]

# %%
predict_df.to_csv('./data/Images_values_target5.csv', encoding='utf-8-sig', index=False)

# %%
base_path = './Class/'
img_base_path = './data/Img_data/'

# %%
def dircheck(dir_path):
    if os.path.exists(dir_path):
        pass
    else:
        os.mkdir(dir_path)
        return

# %%
target_num = predict_df['target'].unique()
eval_list = predict_df['target'].tolist() # 타겟값 리스트화

for num in range(len(target_num)):
    dircheck(f'{base_path}{num}')
    predict_df[predict_df['target'] == int(f'{num}')].to_csv(f'{base_path}{num}/Images_values_target_{num}.csv', encoding='utf-8-sig')
    for i, e in enumerate(eval_list):
        try:
            img_path = os.path.join(img_base_path, f'{i+1}.jpg')
            img = cv2.imread(img_path)
            if e == num:
                cv2.imwrite(os.path.join(f'{base_path}{num}/', f'{i}.jpg'),img)
        except:
            img_path = os.path.join(img_base_path, f'{i+1}.png')
            img = cv2.imread(img_path)
            if e == num:
                cv2.imwrite(os.path.join(f'{base_path}{num}/', f'{i}.jpg'),img)
    print(f'{num}번 타겟 분류완료')
# Out:
# 0번째 타겟 분류완료
# 1번째 타겟 분류완료
# 2번째 타겟 분류완료
# 3번째 타겟 분류완료
# 4번째 타겟 분류완료
